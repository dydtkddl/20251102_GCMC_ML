# %%
import pandas as pd
import os

DF1 = pd.read_csv("../00_1st_collect/273K_merged_dataset.exclude.broken_cif.csv")
DF2 = pd.read_csv("../01_2nd_collect/273K_merged_dataset.exclude.broken_cif.csv")

DF = pd.concat([DF1, DF2] , axis = 1)
DF.to_csv("./273_merged.v1.20251104_0109.csv")
